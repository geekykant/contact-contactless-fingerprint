# %% [markdown]
# ### Downloading Kaggle Dataset

# %%
#setting up Kaggle dataset
! pip install -q kaggle

from google.colab import files
files.upload()

! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-f51e5c9f-906a-4bcc-92f9-f872f9686b53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f51e5c9f-906a-4bcc-92f9-f872f9686b53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
! kaggle datasets download -d peace1019/fingerprint-dataset-for-fvc2000-db4-b
! unzip fingerprint-dataset-for-fvc2000-db4-b.zip
# Out:
# Downloading fingerprint-dataset-for-fvc2000-db4-b.zip to /content
#  39% 10.0M/25.9M [00:00<00:00, 23.0MB/s]
# 100% 25.9M/25.9M [00:00<00:00, 52.1MB/s]
# Archive:  fingerprint-dataset-for-fvc2000-db4-b.zip
#   inflating: dataset_FVC2000_DB4_B/dataset/np_data/img_real.npy
#   inflating: dataset_FVC2000_DB4_B/dataset/np_data/img_train.npy
#   inflating: dataset_FVC2000_DB4_B/dataset/np_data/label_real.npy
#   inflating: dataset_FVC2000_DB4_B/dataset/np_data/label_train.npy
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00000.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00001.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00002.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00003.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00004.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00005.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00006.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00007.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00008.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/real_data/00009.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00000_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00001_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00002_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00003_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00004_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00005_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00006_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00007_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00008_79.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_00.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_01.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_02.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_03.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_04.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_05.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_06.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_07.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_08.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_09.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_10.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_11.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_12.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_13.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_14.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_15.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_16.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_17.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_18.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_19.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_20.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_21.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_22.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_23.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_24.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_25.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_26.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_27.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_28.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_29.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_30.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_31.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_32.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_33.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_34.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_35.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_36.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_37.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_38.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_39.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_40.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_41.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_42.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_43.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_44.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_45.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_46.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_47.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_48.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_49.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_50.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_51.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_52.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_53.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_54.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_55.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_56.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_57.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_58.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_59.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_60.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_61.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_62.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_63.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_64.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_65.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_66.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_67.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_68.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_69.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_70.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_71.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_72.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_73.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_74.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_75.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_76.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_77.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_78.bmp
#   inflating: dataset_FVC2000_DB4_B/dataset/train_data/00009_79.bmp

# %% [markdown]
# ### Building Data

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import random

import os
import datetime

print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("GPU: ", "available" if tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")
# Out:
# Version:  2.4.1
# Eager mode:  True
# GPU:  available

# %%
# load data in train and real
img_data = np.load('dataset_FVC2000_DB4_B/dataset/np_data/img_train.npy')
label_data = np.load('dataset_FVC2000_DB4_B/dataset/np_data/label_train.npy')
img_real = np.load('dataset_FVC2000_DB4_B/dataset/np_data/img_real.npy')
label_real = np.load('dataset_FVC2000_DB4_B/dataset/np_data/label_real.npy')

print(img_data.shape, label_data.shape) #800 => (160 x 160)
print(img_real.shape, label_real.shape) #10 

# split data
img_train_test, img_val, label_train_test, label_val = train_test_split(img_data, label_data, test_size = 0.15)
print(img_data.shape, label_data.shape) #800
print(img_train_test.shape, label_train_test.shape) #720 -> training + testing set
print(img_val.shape, label_val.shape) #80 -> validation set
# Out:
# (800, 160, 160, 1) (800, 1)
# (10, 160, 160, 1) (10, 1)
# (800, 160, 160, 1) (800, 1)
# (680, 160, 160, 1) (680, 1)
# (120, 160, 160, 1) (120, 1)

# %%
# make data
img_train, img_test, label_train, label_test = train_test_split(img_train_test, label_train_test, test_size = 0.15)

# %% [markdown]
# ## Model Initialize & Train

# %%
# model definition
def build_model():
    x1 = layers.Input(shape = (160, 160, 1))
    x2 = layers.Input(shape = (160, 160, 1))

    # share weights both inputs
    inputs = layers.Input(shape = (160, 160, 1))
    feature = layers.Conv2D(32, kernel_size = 3, activation = 'relu')(inputs)
    feature = layers.MaxPooling2D(pool_size = 2)(feature)
    feature = layers.Conv2D(64, kernel_size = 3, activation = 'relu')(feature)
    feature = layers.MaxPooling2D(pool_size = 2)(feature)
    feature = layers.Conv2D(128, kernel_size = 3, activation = 'relu')(feature)
    feature = layers.MaxPooling2D(pool_size = 2)(feature)
    feature_model = Model(inputs = inputs, outputs = feature)

    # show feature model summary
    feature_model.summary()

    # two feature models that sharing weights
    x1_net = feature_model(x1)
    x2_net = feature_model(x2)

    # subtract features
    net = layers.Subtract()([x1_net, x2_net])
    net = layers.Conv2D(128, kernel_size = 3, activation = 'relu')(net)
    net = layers.MaxPooling2D(pool_size = 2)(net)
    net = layers.Flatten()(net)
    net = layers.Dense(512, activation = 'relu')(net)
    net = layers.Dense(1, activation = 'sigmoid')(net)
    model = Model(inputs = [x1, x2], outputs = net)

    # compile
    # model.compile(loss = 'binary_crossentropy', optimizer = optimizers.Adam(lr=1e-3), metrics = ['acc'])
    model.compile(loss = 'binary_crossentropy', optimizer = "adam", metrics = ['acc'])

    # show summary
    # model.summary()
    return (model, feature_model)

# %%
# data generator definition
class DataGenerator(keras.utils.Sequence):
    def __init__(self, img_data, label_data, img_real, label_real, augmentations, batch_size = 32, shuffle = True):
    # def __init__(self, img_data, label_data, img_real, label_real, batch_size = 32, shuffle = True):
        'Initialization'
        self.img_data = img_data
        self.label_data = label_data
        self.img_real = img_real
        self.label_real = label_real
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augment_type = augmentations
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.img_data) / self.batch_size) * 2)

    def __getitem__(self, index):
        'Generate one batch of data'
        real_idx = index
        index = int(np.floor(index / 2))
        img1_batch = self.img_data[index * self.batch_size : (index + 1) * self.batch_size]
        label1_batch = self.label_data[index * self.batch_size : (index + 1) * self.batch_size]
        img2_batch = np.empty((self.batch_size, 160, 160, 1), dtype = np.uint8)
        label2_batch = np.zeros((self.batch_size, 1), dtype = np.uint8)

        img1_batch = np.array([(self.augment_type(image = img)['image']*255).astype(np.uint8) for img in img1_batch], dtype='uint8')
        img2_batch = np.array([(self.augment_type(image = img)['image']*255).astype(np.uint8) for img in img2_batch], dtype='uint8')

        for i, idx in enumerate(label1_batch):
            if random.random() > 0.5:
                # put matched image
                img2_batch[i] = self.img_real[idx]
                label2_batch[i] = 1.
            else:
                # put unmatched image
                while True:
                    unmatch_idx = random.choice(list(self.label_real))
                    if (unmatch_idx != idx):
                        break

                img2_batch[i] = self.img_real[unmatch_idx]
                label2_batch[i] = 0.
                
        index = real_idx
        if (index < int(np.floor(len(self.img_data) / self.batch_size))):
            return [img1_batch.astype(np.float32) / 255., img2_batch.astype(np.float32) / 255.], label2_batch
        
        return [img2_batch.astype(np.float32) / 255., img1_batch.astype(np.float32) / 255.], label2_batch

    def on_epoch_end(self):
        if self.shuffle == True:
            self.img_data, self.label_data = shuffle(self.img_data, self.label_data)

# %%
import cv2
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate
)

AUGMENTATIONS_TRAIN = Compose([
    RandomContrast(limit=0.2, p=0.5),
    RandomBrightness(limit=0.2, p=0.5),
    ShiftScaleRotate(
        shift_limit=0.1, scale_limit=0.2, 
        rotate_limit=15, p=0.8), 
    ToFloat(max_value=255)
])

AUGMENTATIONS_TEST = Compose([
    ToFloat(max_value=255)
])

# %%
train_gen = DataGenerator(img_train, label_train, img_real, label_real, augmentations=AUGMENTATIONS_TRAIN, shuffle = True )
val_gen = DataGenerator(img_val, label_val, img_real, label_real, augmentations=AUGMENTATIONS_TEST, shuffle = True)
test_gen = DataGenerator(img_test, label_test, img_real, label_real, augmentations=AUGMENTATIONS_TEST, shuffle = False)

# %%
print(train_gen.img_data.shape)
print(val_gen.img_data.shape)
print(test_gen.img_data.shape)
# Out:
# (578, 160, 160, 1)
# (120, 160, 160, 1)
# (102, 160, 160, 1)

# %%
# img = train_gen.img_data[0].squeeze()

# for i in range(1,9):
#   plt.title(f'{i}')
#   plt.imshow(AUGMENTATIONS_TRAIN(image = img)['image'], cmap='gray')
#   plt.show()

# %%
# configure checkpoint data
checkpoint_path = 'dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path, save_weights_only = True, verbose = 1)

# prepare tensorboard
if os.name == 'nt':
    tfb_log_dir = 'dataset_FVC2000_DB4_B\\logs\\train\\' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
else:
    tfb_log_dir = 'dataset_FVC2000_DB4_B/logs/train/' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = tfb_log_dir, histogram_freq = 1)

# from tensorflow.keras.callbacks import EarlyStopping
# early_stopping = EarlyStopping(
#     monitor='val_loss', 
#     patience=1, 
#     min_delta=0.20, 
#     mode='auto',
#     restore_best_weights=True
# )

# %%
# prepare model
(model, feature_model) = build_model()
# if (os.path.exists(checkpoint_path + '.index')):
#     print('continue training')
#     model.load_weights(checkpoint_path)
# Out:
# Model: "model_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_42 (InputLayer)        [(None, 160, 160, 1)]     0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 158, 158, 32)      320
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 79, 79, 32)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 77, 77, 64)        18496
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 36, 36, 128)       73856
# _________________________________________________________________
# max_pooling2d_54 (MaxPooling (None, 18, 18, 128)       0
# =================================================================
# Total params: 92,672
# Trainable params: 92,672
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
stop = EarlyStopping(monitor="val_loss", mode="min", patience=6) 

# training model - 700 over batch 64
history = model.fit(train_gen, epochs = 350, validation_data = val_gen, callbacks = [cp_callback, tensorboard_callback, ])
# Out:
# Epoch 1/350
# 36/36 [==============================] - 4s 80ms/step - loss: 0.7237 - acc: 0.4816 - val_loss: 0.7075 - val_acc: 0.4792
#
# Epoch 00001: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 2/350
# 36/36 [==============================] - 2s 54ms/step - loss: 0.6938 - acc: 0.5036 - val_loss: 0.6852 - val_acc: 0.5469
#
# Epoch 00002: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 3/350
# 36/36 [==============================] - 2s 54ms/step - loss: 0.7024 - acc: 0.5304 - val_loss: 0.6851 - val_acc: 0.5781
#
# Epoch 00003: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 4/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.6951 - acc: 0.5182 - val_loss: 0.6890 - val_acc: 0.5260
#
# Epoch 00004: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 5/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.6917 - acc: 0.5324 - val_loss: 0.6926 - val_acc: 0.5104
#
# Epoch 00005: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 6/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.
350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.2701 - acc: 0.8931 - val_loss: 0.3241 - val_acc: 0.8385
#
# Epoch 00118: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 119/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2265 - acc: 0.9055 - val_loss: 0.2269 - val_acc: 0.9115
#
# Epoch 00119: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 120/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2425 - acc: 0.8962 - val_loss: 0.2717 - val_acc: 0.8854
#
# Epoch 00120: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 121/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.2487 - acc: 0.8919 - val_loss: 0.2202 - val_acc: 0.9115
#
# Epoch 00121: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 122/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2176 - acc: 0.9100 - val_loss: 0.2874 - val_acc: 0.8490
#
# Epoch 00122: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 123/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.1870 - acc: 0.9260 - val_loss: 0.2101 - val_acc: 0.9167
#
# Epoch 00123: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 124/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2479 - acc: 0.8977 - val_loss: 0.2736 - val_acc: 0.9062
#
# Epoch 00124: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 125/350
# 36/36 [==============================] - 2s 59ms/step - loss: 0.2363 - acc: 0.8984 - val_loss: 0.2691 - val_acc: 0.9010
#
# Epoch 00125: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 126/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.2033 - acc: 0.9055 - val_loss: 0.3032 - val_acc: 0.8490
#
# Epoch 00126: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 127/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2418 - acc: 0.8878 - val_loss: 0.3392 - val_acc: 0.8854
#
# Epoch 00127: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 128/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2438 - acc: 0.9071 - val_loss: 0.3059 - val_acc: 0.8698
#
# Epoch 00128: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 129/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.2426 - acc: 0.9058 - val_loss: 0.2885 - val_acc: 0.8854
#
# Epoch 00129: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 130/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2609 - acc: 0.8966 - val_loss: 0.2569 - val_acc: 0.9062
#
# Epoch 00130: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 131/350
# 36/36 [==============================] - 2s 58ms/step - loss: 0.1869 - acc: 0.9272 - val_loss: 0.2706 - val_acc: 0.8854
#
# Epoch 00131: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 132/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2367 - acc: 0.8913 - val_loss: 0.2492 - val_acc: 0.9010
#
# Epoch 00132: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 133/350
# 36/36 [==============================] - 2s 55ms/step - loss: 0.2420 - acc: 0.8956 - val_loss: 0.2270 - val_acc: 0.8958
#
# Epoch 00133: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 134/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2328 - acc: 0.8952 - val_loss: 0.2536 - val_acc: 0.9115
#
# Epoch 00134: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 135/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2380 - acc: 0.8967 - val_loss: 0.2393 - val_acc: 0.8854
#
# Epoch 00135: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 136/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2109 - acc: 0.9206 - val_loss: 0.2356 - val_acc: 0.9062
#
# Epoch 00136: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 137/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2181 - acc: 0.9052 - val_loss: 0.3643 - val_acc: 0.8542
#
# Epoch 00137: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 138/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.1787 - acc: 0.9239 - val_loss: 0.2577 - val_acc: 0.8906
#
# Epoch 00138: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 139/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.1882 - acc: 0.9270 - val_loss: 0.2264 - val_acc: 0.9010
#
# Epoch 00139: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 140/350
# 36/36 [==============================] - 2s 54ms/step - loss: 0.2278 - acc: 0.9061 - val_loss: 0.2481 - val_acc: 0.9115
#
# Epoch 00140: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 141/350
# 36/36 [==============================] - 2s 58ms/step - loss: 0.1980 - acc: 0.9257 - val_loss: 0.2464 - val_acc: 0.9010
#
# Epoch 00141: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 142/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2307 - acc: 0.9066 - val_loss: 0.1788 - val_acc: 0.9219
#
# Epoch 00142: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 143/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.1943 - acc: 0.9085 - val_loss: 0.1614 - val_acc: 0.9323
#
# Epoch 00143: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 144/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.1695 - acc: 0.9425 - val_loss: 0.1986 - val_acc: 0.9375
#
# Epoch 00144: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 145/350
# 36/36 [==============================] - 2s 57ms/step - loss: 0.1736 - acc: 0.9241 - val_loss: 0.3363 - val_acc: 0.8594
#
# Epoch 00145: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 146/350
# 36/36 [==============================] - 2s 56ms/step - loss: 0.
saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 336/350
# 36/36 [==============================] - 2s 59ms/step - loss: 0.0630 - acc: 0.9682 - val_loss: 0.2025 - val_acc: 0.9375
#
# Epoch 00336: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 337/350
# 36/36 [==============================] - 2s 59ms/step - loss: 0.0690 - acc: 0.9763 - val_loss: 0.1173 - val_acc: 0.9583
#
# Epoch 00337: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 338/350
# 36/36 [==============================] - 2s 59ms/step - loss: 0.0933 - acc: 0.9691 - val_loss: 0.1608 - val_acc: 0.9531
#
# Epoch 00338: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 339/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0586 - acc: 0.9823 - val_loss: 0.1150 - val_acc: 0.9531
#
# Epoch 00339: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 340/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0596 - acc: 0.9803 - val_loss: 0.1204 - val_acc: 0.9479
#
# Epoch 00340: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 341/350
# 36/36 [==============================] - 2s 59ms/step - loss: 0.0923 - acc: 0.9710 - val_loss: 0.2002 - val_acc: 0.9375
#
# Epoch 00341: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 342/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0964 - acc: 0.9620 - val_loss: 0.2803 - val_acc: 0.9010
#
# Epoch 00342: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 343/350
# 36/36 [==============================] - 2s 59ms/step - loss: 0.0759 - acc: 0.9773 - val_loss: 0.1070 - val_acc: 0.9531
#
# Epoch 00343: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 344/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0811 - acc: 0.9745 - val_loss: 0.1489 - val_acc: 0.9479
#
# Epoch 00344: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 345/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0678 - acc: 0.9755 - val_loss: 0.1488 - val_acc: 0.9792
#
# Epoch 00345: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 346/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0888 - acc: 0.9688 - val_loss: 0.1710 - val_acc: 0.9375
#
# Epoch 00346: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 347/350
# 36/36 [==============================] - 2s 63ms/step - loss: 0.0956 - acc: 0.9664 - val_loss: 0.3252 - val_acc: 0.9062
#
# Epoch 00347: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 348/350
# 36/36 [==============================] - 2s 61ms/step - loss: 0.0694 - acc: 0.9736 - val_loss: 0.1483 - val_acc: 0.9531
#
# Epoch 00348: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 349/350
# 36/36 [==============================] - 2s 60ms/step - loss: 0.0817 - acc: 0.9694 - val_loss: 0.1130 - val_acc: 0.9479
#
# Epoch 00349: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt
# Epoch 350/350
# 36/36 [==============================] - 2s 61ms/step - loss: 0.0626 - acc: 0.9749 - val_loss: 0.1727 - val_acc: 0.9427
#
# Epoch 00350: saving model to dataset_FVC2000_DB4_B/model/checkpoint/cp.ckpt

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.plot(history.history['loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val', 'loss'], loc='upper left')
plt.show()

# %%
print("Train: ", model.evaluate(train_gen))
print("Validation: ", model.evaluate(val_gen))
print("Test: ", model.evaluate(test_gen))
# Out:
# 36/36 [==============================] - 1s 40ms/step - loss: 0.0736 - acc: 0.9705
# Train:  [0.07360485196113586, 0.9704861044883728]
# 6/6 [==============================] - 0s 21ms/step - loss: 0.1507 - acc: 0.9375
# Validation:  [0.1507081538438797, 0.9375]
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1096 - acc: 0.9635
# Test:  [0.10957237333059311, 0.9635416865348816]

# %% [markdown]
# ## Save & Load Model

# %%
# save model
model_path = 'dataset_FVC2000_DB4_B/model/12_120_fp160.h5'
model_feature_path = 'dataset_FVC2000_DB4_B/model/12_120_fp160_feature.h5'
model.save(model_path)
feature_model.save(model_feature_path)

# %%
# load model
model_path = 'dataset_FVC2000_DB4_B/model/fp160.h5'
model_feature_path = 'dataset_FVC2000_DB4_B/model/fp160_feature.h5'
feature_model = tf.keras.models.load_model(model_feature_path)
model = tf.keras.models.load_model(model_path)
# feature_model.summary()
# model.summary()

# %% [markdown]
# ## Testing

# %%
# check test images accuracy

import random
input_idx = random.randint(0,len(img_test)) #test images
my_test_img = img_test[input_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.

preds = []
best_pred_image = None
best_pred_pred = 0

for db_idx in range(10):
  db_img = img_real[db_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
  pred = model.predict([my_test_img, db_img])
  preds.append(pred[0][0])
  if(pred[0][0] > best_pred_pred):
    best_pred_pred = pred[0][0]
    best_pred_image = db_img

plt.bar(range(10), preds)
plt.show()

print(preds)

# show result
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.title('Input: %s Required: %d' %(input_idx, label_test[input_idx]))
plt.imshow(my_test_img.squeeze(), cmap='gray')

plt.subplot(1, 2, 2) 
plt.title('O: %.02f, %s' % (max(preds), preds.index(max(preds))))
plt.imshow(best_pred_image.squeeze(), cmap='gray')
# Out:
# [3.588939e-08, 1.5014758e-06, 0.00031520304, 0.9658035, 0.00011994406, 0.00022354399, 0.03298241, 2.0631014e-06, 9.317462e-10, 1.4248398e-11]

# %%
# test images error count. (comparing with 10 fingers & taking best pred)

threshs = [0.65, 0.7, 0.75, 0.8, 0.85]
thresh_errors = {
    "0.65" : 0,
    "0.7": 0,
    "0.75": 0,
    "0.8": 0,
    "0.85": 0
}

err = 0
for input_idx in range(0,len(img_test)): #test images
    my_test_img = img_test[input_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.

    best_pred_index = -1
    best_pred_pred = 0

    for db_idx in range(10):
      db_img = img_real[db_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
      pred = model.predict([my_test_img, db_img])

      # if pred[0][0] > 0.85 and label_test[input_idx] != db_idx:
      #     err += 1
      #finding the best out of 10 fingers
      
      if pred[0][0] > best_pred_pred:
        best_pred_pred = pred[0][0]
        best_pred_index = label_real[db_idx]

    for thresh in threshs:
      if label_test[input_idx] != best_pred_index or best_pred_pred < thresh:
        thresh_errors[str(thresh)] += 1

for thresh in threshs:
  print("thresh: %.2f" %thresh , " -- ", "error count: ", thresh_errors[str(thresh)] , " -- ", "out of: ", len(img_test))
# Out:
# thresh: 0.65  --  error count:  11  --  out of:  102
# thresh: 0.70  --  error count:  11  --  out of:  102
# thresh: 0.75  --  error count:  11  --  out of:  102
# thresh: 0.80  --  error count:  15  --  out of:  102
# thresh: 0.85  --  error count:  16  --  out of:  102

# %% [markdown]
# ## Unused Codes

# %%
#list all test data 1-1 (one to one)
# total_count = 0
# err_count = 0

# for input_idx in range(label_test.shape[0]):
#     print('Processing #', input_idx, ' => ', label_test[input_idx])

#     my_test_img = img_test[input_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
#     for db_idx in range(10):
#       db_img = img_real[db_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
#       pred = model.predict([my_test_img, db_img])

#       # print(f"{label_test[input_idx]}-{label_real[db_idx]} --> %.4f" %pred[0][0])
#       if pred[0][0] > 0.85 and label_test[input_idx] != label_real[db_idx]:
#         err_count += 1

#     total_count += 1

# # show result
# print('Evaluation Finished')
# print(f"Error count: {err_count}")
# print(f'Total count: {total_count * 10}')

# %%
# # Evaluate real image
# total_count = 0
# error_count = 0
# error_rage = 0.85

# for input_idx in range(label_real.shape[0]):
#     print('Processing #', input_idx, '')
#     best_pred_pred = 0
#     best_pred_index = -1

#     for db_idx in range(10):
#       db_img = img_real[db_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
#       pred = model.predict([my_test_img, db_img])
#       if(pred[0][0] > best_pred_pred):
#         best_pred_pred = pred[0][0]
#         best_pred_index = db_idx

#       print(f"{input_idx}-{db_idx} --> %.2f" %pred[0][0])
    
#     # if (label_real[input_idx] == best_pred_index):
#     #     if (best_pred_pred < error_rage):
#     #         print('False Reject = ', best_pred_pred)
#     #         error_count += 1
#     # else:
#     #     if (best_pred_pred > error_rage):
#     #         print('False Accept = ', best_pred_pred, ', ID = ', input_idx)
#     #         error_count += 1
#     total_count += 1

# # show result
# print('Evaluation Finished')
# print('Total Count = ', total_count)
# print('Error Count = ', error_count)
# print('Error Rate = ', (error_count / total_count) * 100, '%')

# %%
#manual checking two indices images

# input_idx = 1
# db_idx = 1
# input_img = img_real[input_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
# db_img = img_real[db_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
# pred_right = model.predict([input_img, db_img])

# # show result
# plt.figure(figsize=(8, 4))
# plt.subplot(1, 2, 1)
# plt.title('Input: %s' %input_idx)
# plt.imshow(input_img.squeeze(), cmap='gray')
# plt.subplot(1, 2, 2)
# plt.title('O: %.02f, %s' % (pred_right, db_idx))
# plt.imshow(db_img.squeeze(), cmap='gray')

# %%
# # Evaluate train data
# total_count = 0
# error_count = 0
# error_rage = 0.9

# for input_idx in range(label_data.shape[0]):
#     print('Processing #', input_idx, '')
#     for db_idx in range(label_data.shape[0]):
#         input_img = img_data[input_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
#         db_img = img_data[db_idx].reshape((1, 160, 160, 1)).astype(np.float32) / 255.
#         pred_right = model.predict([input_img, db_img])
#         if (input_idx == db_idx):
#             if (pred_right < error_rage):
#                 print('False Reject = ', pred_right)
#                 error_count += 1
#         if (input_idx != db_idx):
#             if (pred_right > error_rage):
#                 print('False Accept = ', pred_right, ', ID = ', db_idx)
#                 error_count += 1
#         total_count += 1

# # show result
# print('Evaluation Finished')
# print('Total Count = ', total_count)
# print('Error Count = ', error_count)
# print('Error Rate = ', (error_count / total_count) * 100)

# %% [markdown]
# ## Contactless Testing

# %%
#Contactless images testing (REAL PART)
import cv2

input_idx = 'L'
db_idx = 'R'

def two_image_prediction(input1_file, input2_file):
    input1_img = cv2.imread(input1_file, cv2.IMREAD_GRAYSCALE)
    input1_img = input1_img.reshape((1, 160, 160, 1)).astype(np.float32) / 255.
    input2_img = cv2.imread(input2_file, cv2.IMREAD_GRAYSCALE)
    input2_img = input2_img.reshape((1, 160, 160, 1)).astype(np.float32) / 255.
    pred_right = model.predict([input1_img, input2_img])

    print("Prediction %.10f" %pred_right[0][0])

    plt.figure(figsize=(8, 4)).suptitle("Prediction %.10f" %pred_right[0][0])
    plt.subplot(1, 2, 1)
    plt.title('Input: %s' %input_idx)
    plt.imshow(input1_img.squeeze(), cmap='gray')
    plt.subplot(1, 2, 2)
    plt.title('O: %s' % (db_idx))
    plt.imshow(input2_img.squeeze(), cmap='gray')

# input1_file = '1.png'
# input2_file = '2.png'

#checking contactless i/p images one to one (1-1)
for i in range(1,5):
  for j in range(1,5):
    two_image_prediction(f'{i}.png', f'{j}.png')
# Out:
# Prediction 0.9999216795
# Prediction 0.5390782952
# Prediction 0.0001818415
# Prediction 0.0002584809
# Prediction 0.5190097094
# Prediction 0.9999216795
# Prediction 0.0446197763
# Prediction 0.2715327442
# Prediction 0.2383855432
# Prediction 0.3209569454
# Prediction 0.9999216795
# Prediction 0.8545214534
# Prediction 0.1244095862
# Prediction 0.1144467220
# Prediction 0.4938254952
# Prediction 0.9999216795
